# %% [markdown]
# # Imporiting relavant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import scipy.io
import tarfile
import csv
import sys
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import optimizers
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dense, Dropout, Flatten
from pathlib import Path
import numpy as np
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping
from keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.inputs.keras import PlotLossesCallback
from tensorflow.keras import layers
from tensorflow.keras.applications import VGG16
import tensorflow as tf
from skimage import io
import PIL
from PIL import ImageOps, ImageFilter
#increase default chart size
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
# %matplotlib inline

# %% [markdown]
# # Loading the data

# %%
DATA_PATH = "/Users/esraan/Downloads/ML_3/jpg/"
PATH = "/Users/esraan/Downloads/ML_3/"

# %%
# Setting seed for reproducibility
#os.makedirs(PATH,exist_ok=False)

RANDOM_SEED = 33
np.random.seed(RANDOM_SEED)  
PYTHONHASHSEED = 0

# %%
# read all file names directly from the archive and targets for them
def get_all_filenames(tar_fn):
    with tarfile.open(tar_fn) as f:
        return [m.name for m in f.getmembers() if m.isfile()]

df = pd.DataFrame()
df['Id'] = sorted([f for f in os.listdir(DATA_PATH) if not os.path.isfile(f)])
#files = [f for f in os.listdir(DATA_PATH) if os.path.isfile(f)]
df['Category'] = scipy.io.loadmat(PATH+'imagelabels.mat')['labels'][0] 
df['Category'] = df['Category'].astype(str)

df.head()
# Out:
#                 Id Category
# 0  image_00001.jpg       77
# 1  image_00002.jpg       77
# 2  image_00003.jpg       77
# 3  image_00004.jpg       77
# 4  image_00005.jpg       77

# %% [markdown]
# # Visualizing Random sample of images for different classes

# %%
print('Sample pictures (random sample)')
plt.figure(figsize=(12,8))

random_image = df.sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values
PATH_1=DATA_PATH
for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH_1+path)
    plt.subplot(3,3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')
plt.show()
# Out:
# Sample pictures (random sample)

# %% [markdown]
# # Visualizing Random sample of images for class 4

# %%
# make sure the class labels are loaded correctly
print('Sample pictures (random sample)')
plt.figure(figsize=(12,8))

random_image = df[df['Category']=='4'].sample(n=9)
random_image_paths = random_image['Id'].values
random_image_cat = random_image['Category'].values

for index, path in enumerate(random_image_paths):
    im = PIL.Image.open(PATH_1+path)
    plt.subplot(3,3, index+1)
    plt.imshow(im)
    plt.title('Class: '+str(random_image_cat[index]))
    plt.axis('off')
plt.show()
# Out:
# Sample pictures (random sample)

# %%
# as you can see the images have different sizes
image = PIL.Image.open(PATH_1+path)
imgplot = plt.imshow(image)
plt.show()
image.size
# Out:
# (500, 752)

# %% [markdown]
# # splitting the Data randomly (by seed=33) into train/test/validation

# %%
# train / test
train_files, test_files, train_labels, test_labels= \
    train_test_split(df['Id'], df['Category'], test_size=0.25, random_state=33, stratify=df['Category'])

train_files = pd.DataFrame(train_files)
test_files = pd.DataFrame(test_files)

train_files['Category'] = train_labels
test_files['Category'] = test_labels


train_files.shape, test_files.shape
# Out:
# ((6141, 2), (2048, 2))

# %%
train_files, val_files, train_labels, val_labels = \
    train_test_split(train_files['Id'], train_files['Category'], test_size=0.333334, random_state=33, stratify=train_files['Category'])

train_files = pd.DataFrame(train_files)
val_files = pd.DataFrame(val_files)
train_files['Category'] = train_labels
val_files['Category'] = val_labels

val_files.shape, test_files.shape, train_files.shape
# Out:
# ((2048, 2), (2048, 2), (4093, 2))

# %% [markdown]
# # using ImageDataGenerator for Rescaling and Augmentation

# %%
# we put the main settings in the setup, so it’s more convenient to sort them out in the future
BATCH_SIZE           = 32 

CLASS_NUM            = 102
IMG_SIZE             = 224
IMG_CHANNELS         = 3
input_shape          = (IMG_SIZE, IMG_SIZE, IMG_CHANNELS)

# %%
# Data augmentation is very important when we do not have a large dataset (as in our case)

train_datagen = ImageDataGenerator(rescale=1. / 255, 
                                    rotation_range = 50,
                                    shear_range=0.2,
                                    zoom_range=[0.75,1.25],
                                    brightness_range=[0.5, 1.5],
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    horizontal_flip=True,
                                    vertical_flip=True)
val_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# # "Wrapping" our data in a generator

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_files,
    directory=PATH_1,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=True, 
    seed=RANDOM_SEED)

val_generator = val_datagen.flow_from_dataframe(
    dataframe=val_files,
    directory=PATH_1,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=True, 
    seed=RANDOM_SEED)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_files,
    directory=PATH_1,
    x_col="Id",
    y_col="Category",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=False, 
    seed=RANDOM_SEED)
# Out:
# Found 4093 validated image filenames belonging to 102 classes.
# Found 2048 validated image filenames belonging to 102 classes.
# Found 2048 validated image filenames belonging to 102 classes.

# %%
test_generator.image_shape
# Out:
# (224, 224, 3)

# %%
def imshow(image_RGB):
  io.imshow(image_RGB)
  io.show()

x,y = train_generator.next()
print('Sample pictures from train_generator')
plt.figure(figsize=(12,8))

for i in range(0,6):
    image = x[i]
    plt.subplot(3,3, i+1)
    plt.imshow(image)
    #plt.title('Class: '+str(y[i]))
    #plt.axis('off')
plt.show()
# Out:
# Sample pictures from train_generator

# %% [markdown]
# # Using the pre-trained VGG16 model and rebuilding the top layers

# %%
plot_loss_1 = PlotLossesCallback()

# ModelCheckpoint callback - save best weights
tl_checkpoint_1 = ModelCheckpoint(filepath='tl_model_v1.weights.best.hdf5',
                                  save_best_only=True,
                                  verbose=1)

# EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')

# %%
pip install livelossplot
# Out:
# Requirement already satisfied: livelossplot in c:\users\esraan\anaconda3\lib\site-packages (0.5.5)
# Requirement already satisfied: bokeh in c:\users\esraan\anaconda3\lib\site-packages (from livelossplot) (2.3.2)
# Requirement already satisfied: matplotlib in c:\users\esraan\anaconda3\lib\site-packages (from livelossplot) (3.3.4)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (2.11.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (3.7.4.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (6.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (1.20.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (20.9)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (8.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (5.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\esraan\anaconda3\lib\site-packages (from bokeh->livelossplot) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\esraan\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh->livelossplot) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\esraan\anaconda3\lib\site-packages (from packaging>=16.8->bokeh->livelossplot) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\esraan\anaconda3\lib\site-packages (from python-dateutil>=2.1->bokeh->livelossplot) (1.15.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\esraan\anaconda3\lib\site-packages (from matplotlib->livelossplot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\esraan\anaconda3\lib\site-packages (from matplotlib->livelossplot) (0.10.0)

# %%
NUM_CLASSES=102
inputs = layers.Input(shape=input_shape)

base_model = tf.keras.applications.VGG16(include_top=False, input_tensor=inputs, weights="imagenet")

# Freeze the pretrained weights
base_model.trainable = False

# Rebuild top
x = layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
x = layers.BatchNormalization()(x)

top_dropout_rate = 0.2
x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="pred")(x)

# Compile
model = tf.keras.Model(inputs, outputs, name="VGG16")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(
    optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# %%
len(model.trainable_variables)
# Out:
# 4

# %%
model.summary()
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  avg_pool (GlobalAveragePool  (None, 512)              0
#  ing2D)
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  top_dropout (Dropout)       (None, 512)               0
#
#  pred (Dense)                (None, 102)               52326
#
# =================================================================
# Total params: 14,769,062
# Trainable params: 53,350
# Non-trainable params: 14,715,712
# _________________________________________________________________

# %% [markdown]
# # fitting the model on the data and evaluating it

# %%
initial_epochs = 11
loss0, accuracy0 = model.evaluate(val_generator)
# Out:
# 64/64 [==============================] - 263s 4s/step - loss: 4.9386 - accuracy: 0.0161

# %%
# %%time 
history = model.fit(train_generator,
                    epochs=initial_epochs,
                    validation_data=val_generator,
                    callbacks=[tl_checkpoint_1, early_stop])
# Out:
# Epoch 1/11
# 128/128 [==============================] - ETA: 0s - loss: 3.8933 - accuracy: 0.1534
# Epoch 1: val_loss improved from inf to 3.98533, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 774s 6s/step - loss: 3.8933 - accuracy: 0.1534 - val_loss: 3.9853 - val_accuracy: 0.1284
# Epoch 2/11
# 128/128 [==============================] - ETA: 0s - loss: 2.5600 - accuracy: 0.3865
# Epoch 2: val_loss improved from 3.98533 to 3.05316, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 822s 6s/step - loss: 2.5600 - accuracy: 0.3865 - val_loss: 3.0532 - val_accuracy: 0.4224
# Epoch 3/11
# 128/128 [==============================] - ETA: 0s - loss: 2.0623 - accuracy: 0.4991
# Epoch 3: val_loss improved from 3.05316 to 2.18612, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 764s 6s/step - loss: 2.0623 - accuracy: 0.4991 - val_loss: 2.1861 - val_accuracy: 0.5488
# Epoch 4/11
# 128/128 [==============================] - ETA: 0s - loss: 1.7758 - accuracy: 0.5583
# Epoch 4: val_loss improved from 2.18612 to 1.63561, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 756s 6s/step - loss: 1.7758 - accuracy: 0.5583 - val_loss: 1.6356 - val_accuracy: 0.6304
# Epoch 5/11
# 128/128 [==============================] - ETA: 0s - loss: 1.5701 - accuracy: 0.6113
# Epoch 5: val_loss improved from 1.63561 to 1.37203, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 776s 6s/step - loss: 1.5701 - accuracy: 0.6113 - val_loss: 1.3720 - val_accuracy: 0.6650
# Epoch 6/11
# 128/128 [==============================] - ETA: 0s - loss: 1.4293 - accuracy: 0.6377
# Epoch 6: val_loss improved from 1.37203 to 1.23627, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 757s 6s/step - loss: 1.4293 - accuracy: 0.6377 - val_loss: 1.2363 - val_accuracy: 0.6792
# Epoch 7/11
# 128/128 [==============================] - ETA: 0s - loss: 1.3303 - accuracy: 0.6624
# Epoch 7: val_loss improved from 1.23627 to 1.15733, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 754s 6s/step - loss: 1.3303 - accuracy: 0.6624 - val_loss: 1.1573 - val_accuracy: 0.6934
# Epoch 8/11
# 128/128 [==============================] - ETA: 0s - loss: 1.2488 - accuracy: 0.6770
# Epoch 8: val_loss improved from 1.15733 to 1.10470, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 752s 6s/step - loss: 1.2488 - accuracy: 0.6770 - val_loss: 1.1047 - val_accuracy: 0.7046
# Epoch 9/11
# 128/128 [==============================] - ETA: 0s - loss: 1.1589 - accuracy: 0.6995
# Epoch 9: val_loss improved from 1.10470 to 1.08151, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 759s 6s/step - loss: 1.1589 - accuracy: 0.6995 - val_loss: 1.0815 - val_accuracy: 0.7007
# Epoch 10/11
# 128/128 [==============================] - ETA: 0s - loss: 1.1225 - accuracy: 0.7034
# Epoch 10: val_loss improved from 1.08151 to 1.04097, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 754s 6s/step - loss: 1.1225 - accuracy: 0.7034 - val_loss: 1.0410 - val_accuracy: 0.7192
# Epoch 11/11
# 128/128 [==============================] - ETA: 0s - loss: 1.0880 - accuracy: 0.7102
# Epoch 11: val_loss improved from 1.04097 to 1.00586, saving model to tl_model_v1.weights.best.hdf5
# 128/128 [==============================] - 753s 6s/step - loss: 1.0880 - accuracy: 0.7102 - val_loss: 1.0059 - val_accuracy: 0.7295
# Wall time: 2h 20min 20s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.grid(False)
plt.title('Training and Validation Accuracy seed 33')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,0.1])
plt.title('Training and Validation Loss seed 33')
plt.xlabel('epoch')
plt.grid(False)
plt.show()

# %% [markdown]
# # Fine-Tuning VGG16 model

# %%
model.trainable = True

# %%
len(model.layers)
# Out:
# 23

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 17

# Freeze all the layers before the `fine_tune_at` layer
for layer in model.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  23

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.Adam(learning_rate=5.0e-5),
              metrics=['accuracy'])

# %%
len(model.trainable_variables)
# Out:
# 6

# %%
model.summary()
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  avg_pool (GlobalAveragePool  (None, 512)              0
#  ing2D)
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  top_dropout (Dropout)       (None, 512)               0
#
#  pred (Dense)                (None, 102)               52326
#
# =================================================================
# Total params: 14,769,062
# Trainable params: 2,413,158
# Non-trainable params: 12,355,904
# _________________________________________________________________

# %%
fine_tune_epochs = 10
initial_epochs = 11
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = model.fit(train_generator,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=val_generator)
# Out:
# Epoch 11/21
# C:\Users\esraan\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 128/128 [==============================] - 776s 6s/step - loss: 0.9656 - accuracy: 0.7410 - val_loss: 1.0125 - val_accuracy: 0.7402
# Epoch 12/21
# 128/128 [==============================] - 774s 6s/step - loss: 0.8347 - accuracy: 0.7711 - val_loss: 0.9079 - val_accuracy: 0.7559
# Epoch 13/21
# 128/128 [==============================] - 772s 6s/step - loss: 0.7412 - accuracy: 0.7975 - val_loss: 0.8279 - val_accuracy: 0.7739
# Epoch 14/21
# 128/128 [==============================] - 775s 6s/step - loss: 0.6974 - accuracy: 0.8038 - val_loss: 0.7335 - val_accuracy: 0.7939
# Epoch 15/21
# 128/128 [==============================] - 1586s 12s/step - loss: 0.6328 - accuracy: 0.8236 - val_loss: 0.7329 - val_accuracy: 0.8027
# Epoch 16/21
# 128/128 [==============================] - 793s 6s/step - loss: 0.6206 - accuracy: 0.8292 - val_loss: 0.6760 - val_accuracy: 0.8071
# Epoch 17/21
# 128/128 [==============================] - 796s 6s/step - loss: 0.5663 - accuracy: 0.8348 - val_loss: 0.7020 - val_accuracy: 0.8105
# Epoch 18/21
# 128/128 [==============================] - 775s 6s/step - loss: 0.5559 - accuracy: 0.8439 - val_loss: 0.7026 - val_accuracy: 0.8110
# Epoch 19/21
# 128/128 [==============================] - 773s 6s/step - loss: 0.5144 - accuracy: 0.8471 - val_loss: 0.6586 - val_accuracy: 0.8213
# Epoch 20/21
# 128/128 [==============================] - 772s 6s/step - loss: 0.4702 - accuracy: 0.8686 - val_loss: 0.6510 - val_accuracy: 0.8193
# Epoch 21/21
# 128/128 [==============================] - 821s 6s/step - loss: 0.4765 - accuracy: 0.8656 - val_loss: 0.6191 - val_accuracy: 0.8340

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
#plt.ylim([0.8, 1])
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy seed 33')
plt.grid(False)
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
#plt.ylim([0, 1.0])
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss seed 33')
plt.gcf().savefig('Training and Validation Loss and accuracy after tunning seed 33')
plt.grid(False)
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # hyper-parameter tuning of VGG16

# %%
epochs = 30

# Reduce learning rate when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.01,
                                                 patience = 3,
                                                 factor = 0.25,
                                                 verbose = 1,
                                                 cooldown = 0,
                                                 min_lr = 0.00000001)

# Stop the training process when there is a change lesser than <min_delta> in <val_accuracy> for more than <patience> epochs
early_stopper = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 mode = 'max',
                                                 min_delta = 0.005,
                                                 patience = 10,
                                                 verbose = 1,
                                                 restore_best_weights = True)

# %%
#fit the model
history = model.fit(train_generator, 
                    epochs=epochs,
                    validation_data = val_generator,
                    callbacks=[early_stopper, reduce_lr])
# Out:
# Epoch 1/30
# 128/128 [==============================] - 781s 6s/step - loss: 0.4304 - accuracy: 0.8783 - val_loss: 0.6014 - val_accuracy: 0.8335 - lr: 5.0000e-05
# Epoch 2/30
# 128/128 [==============================] - 769s 6s/step - loss: 0.4400 - accuracy: 0.8747 - val_loss: 0.6076 - val_accuracy: 0.8359 - lr: 5.0000e-05
# Epoch 3/30
# 128/128 [==============================] - 771s 6s/step - loss: 0.4369 - accuracy: 0.8781 - val_loss: 0.6174 - val_accuracy: 0.8271 - lr: 5.0000e-05
# Epoch 4/30
# 128/128 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8810
# Epoch 4: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 128/128 [==============================] - 771s 6s/step - loss: 0.4028 - accuracy: 0.8810 - val_loss: 0.5889 - val_accuracy: 0.8350 - lr: 5.0000e-05
# Epoch 5/30
# 128/128 [==============================] - 778s 6s/step - loss: 0.3693 - accuracy: 0.8932 - val_loss: 0.5367 - val_accuracy: 0.8511 - lr: 1.2500e-05
# Epoch 6/30
# 128/128 [==============================] - 773s 6s/step - loss: 0.3338 - accuracy: 0.9054 - val_loss: 0.5288 - val_accuracy: 0.8574 - lr: 1.2500e-05
# Epoch 7/30
# 128/128 [==============================] - 769s 6s/step - loss: 0.3477 - accuracy: 0.9047 - val_loss: 0.5277 - val_accuracy: 0.8555 - lr: 1.2500e-05
# Epoch 8/30
# 128/128 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.8998
# Epoch 8: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 128/128 [==============================] - 770s 6s/step - loss: 0.3466 - accuracy: 0.8998 - val_loss: 0.5183 - val_accuracy: 0.8560 - lr: 1.2500e-05
# Epoch 9/30
# 128/128 [==============================] - 768s 6s/step - loss: 0.3435 - accuracy: 0.9069 - val_loss: 0.5191 - val_accuracy: 0.8599 - lr: 3.1250e-06
# Epoch 10/30
# 128/128 [==============================] - 4811s 38s/step - loss: 0.3399 - accuracy: 0.9057 - val_loss: 0.5187 - val_accuracy: 0.8584 - lr: 3.1250e-06
# Epoch 11/30
# 128/128 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.9064
# Epoch 11: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 128/128 [==============================] - 769s 6s/step - loss: 0.3357 - accuracy: 0.9064 - val_loss: 0.5181 - val_accuracy: 0.8574 - lr: 3.1250e-06
# Epoch 12/30
# 128/128 [==============================] - 770s 6s/step - loss: 0.3433 - accuracy: 0.9035 - val_loss: 0.5194 - val_accuracy: 0.8579 - lr: 7.8125e-07
# Epoch 13/30
# 128/128 [==============================] - 765s 6s/step - loss: 0.3304 - accuracy: 0.9094 - val_loss: 0.5185 - val_accuracy: 0.8584 - lr: 7.8125e-07
# Epoch 14/30
# 128/128 [==============================] - ETA: 0s - loss: 0.3389 - accuracy: 0.9084
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 128/128 [==============================] - 768s 6s/step - loss: 0.3389 - accuracy: 0.9084 - val_loss: 0.5187 - val_accuracy: 0.8594 - lr: 7.8125e-07
# Epoch 15/30
# 128/128 [==============================] - 1670s 13s/step - loss: 0.3307 - accuracy: 0.9072 - val_loss: 0.5191 - val_accuracy: 0.8599 - lr: 1.9531e-07
# Epoch 16/30
# 128/128 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.9094Restoring model weights from the end of the best epoch: 6.
# 128/128 [==============================] - 782s 6s/step - loss: 0.3264 - accuracy: 0.9094 - val_loss: 0.5185 - val_accuracy: 0.8589 - lr: 1.9531e-07
# Epoch 16: early stopping

# %%
#get results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

#plot results
#accuracy
plt.figure(figsize=(8, 8))
plt.rcParams['figure.figsize'] = [16, 9]
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.facecolor'] = 'white'
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title(f'VGG16 \nTraining and Validation Accuracy. \nTrain Accuracy: {str(acc[-1])}\nValidation Accuracy: {str(val_acc[-1])}')
plt.grid(False)
#loss
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title(f'Training and Validation Loss. \nTrain Loss: {str(loss[-1])}\nValidation Loss: {str(val_loss[-1])}')
plt.xlabel('epoch')
plt.tight_layout(pad=3.0)
plt.gcf().savefig('Training and Validation Loss and accuracy final seed 33')
plt.grid(False)
plt.show()

# %%
scores = model.evaluate(test_generator)
# Out:
# 64/64 [==============================] - 253s 4s/step - loss: 0.5466 - accuracy: 0.8550

# %%
model.summary()
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  avg_pool (GlobalAveragePool  (None, 512)              0
#  ing2D)
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  top_dropout (Dropout)       (None, 512)               0
#
#  pred (Dense)                (None, 102)               52326
#
# =================================================================
# Total params: 14,769,062
# Trainable params: 2,413,158
# Non-trainable params: 12,355,904
# _________________________________________________________________
